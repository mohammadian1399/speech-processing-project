# %%
from google.colab import drive
drive.mount("/content/gdrive")
% cd "gdrive/MyDrive/Colab Notebooks/FullSubNet"
# !ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/.shortcut-targets-by-id/1bclofPcrojSj0l4xeSPGN89voQYd8Mab/FullSubNet
# audio_zen  audio_zen2  data  dns-data  docs  recipes  tools  train

# %%
% cd 'recipes/dns_interspeech_2020/'
# !ls
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/FullSubNet/recipes/dns_interspeech_2020
# dataset_inference.py   fullsubnet_best_model_58epochs.tar  __init__.py
# dataset_train.py       inference.ipynb			   out
# dataset_validation.py  inference.py			   __pycache__
# fullband_baseline      inferencer.ipynb			   train.ipynb
# fullsubnet	       inferencer.py			   train.py

# %% [markdown]
# ## Use Pre-trained Model

# %%
# !python inference.py \
  -C fullsubnet/inference.toml \
  -M fullsubnet_best_model_58epochs.tar \
  -O out
# Out:
# Using CPU in the experiment.
# Loading inference dataset...
# Loading model...
# Loading model checkpoint (epoch == 58)...
# Configurations are as follows:
# [acoustics]
# sr = 16000
# n_fft = 512
# win_length = 512
# hop_length = 256
#
# [inferencer]
# path = "inferencer.Inferencer"
# type = "full_band_crm_mask"
#
# [dataset]
# path = "dataset_inference.Dataset"
#
# [model]
# path = "fullsubnet.model.Model"
#
# [inferencer.args]
# n_neighbor = 15
#
# [dataset.args]
# dataset_dir_list = [ "/content/gdrive/MyDrive/Colab Notebooks/FullSubNet/data/noise",]
# sr = 16000
#
# [model.args]
# sb_num_neighbors = 15
# fb_num_neighbors = 0
# num_freqs = 257
# look_ahead = 2
# sequence_model = "LSTM"
# fb_output_activate_function = "ReLU"
# sb_output_activate_function = false
# fb_model_hidden_size = 512
# sb_model_hidden_size = 384
# weight_init = false
# norm_type = "offline_laplace_norm"
# num_groups_in_drop_band = 2
#
# ...

# %% [markdown]
# ## Train our model

# %%
# !pip install librosa pesq pypesq pystoi tqdm toml mir_eval torch_complex rich
# Out:
# ...
#      |████████████████████████████████| 87 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 209 kB 56.2 MB/s
# ...
#      |████████████████████████████████| 51 kB 7.4 MB/s
# ...
#   Created wheel for pesq: filename=pesq-0.0.3-cp37-cp37m-linux_x86_64.whl size=209966 sha256=32d9f379e35aa6ccb294dfdebf1e79d4214c828ddc8d680a2dd591f69c3f768f
#   Stored in directory: /root/.cache/pip/wheels/4f/67/5b/aa7cf31fe0c7199e35c604bb7bc91c629a13726bf221fedba0
# ...
#   Created wheel for pypesq: filename=pypesq-1.2.4-cp37-cp37m-linux_x86_64.whl size=84267 sha256=158ba63a72dde24dada0d1acb7922fc9b780e5c487bfd673adf447a427fa6017
#   Stored in directory: /root/.cache/pip/wheels/48/b5/16/d9a8d51220781689bf670dfcb9ccfdabf45ef26168b052b139
# ...
#   Created wheel for pystoi: filename=pystoi-0.3.3-py2.py3-none-any.whl size=7794 sha256=2f09b0c68d82891e1a1673b397db1ccbdd9433cdfd8d80cfe29bcaf952c3d341
#   Stored in directory: /root/.cache/pip/wheels/46/4a/ad/3ab460193ed0535430b4b1575f255aa6bae69df17453628e86
# ...

# %%
# !pip install pytorch torchvision torchaudio cudatoolkit==10.2
# Out:
# ...
#      |████████████████████████████████| 1.9 MB 6.8 MB/s
# ERROR: Could not find a version that satisfies the requirement cudatoolkit==10.2 (from versions: none)
# ERROR: No matching distribution found for cudatoolkit==10.2

# %%
# !python train.py -C fullsubnet/train.toml -N 1
# Out:
# 1/1 process initialized.
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2021-08-07 23:55:55.067629: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# The configurations are as follows:
# {
#     'meta': {
#         'save_dir': '/content/gdrive/MyDrive/Colab Notebooks/FullSubNet',
#         'description': 'This is a description of FullSubNet experiment.',
#         'seed': 0,
#         'use_amp': True,
#         'cudnn_enable': True,
#         'experiment_name': 'train',
# ...

# %% [markdown]
# ## Use our trained model

# %%
# !python inference.py \
  -C fullsubnet/inference.toml \
  -M "../../train/checkpoints/best_model.tar" \
  -O out_our
# Out:
# Loading inference dataset...
# Loading model...
# Loading model checkpoint (epoch == 3)...
# Configurations are as follows:
# [acoustics]
# sr = 16000
# n_fft = 512
# win_length = 512
# hop_length = 256
#
# [inferencer]
# path = "inferencer.Inferencer"
# type = "full_band_crm_mask"
#
# [dataset]
# path = "dataset_inference.Dataset"
#
# [model]
# path = "fullsubnet.model.Model"
#
# [inferencer.args]
# n_neighbor = 15
#
# [dataset.args]
# dataset_dir_list = [ "/content/gdrive/MyDrive/Colab Notebooks/FullSubNet/data/test/no_reverb/noisy",]
# sr = 16000
#
# [model.args]
# sb_num_neighbors = 15
# fb_num_neighbors = 0
# num_freqs = 257
# look_ahead = 2
# sequence_model = "LSTM"
# fb_output_activate_function = "ReLU"
# sb_output_activate_function = false
# fb_model_hidden_size = 512
# sb_model_hidden_size = 384
# weight_init = false
# norm_type = "offline_laplace_norm"
# num_groups_in_drop_band = 2
#
# ...

# %% [markdown]
# ## Calculate metrcis on our model results

# %%
# metrics
# !python calculate_metrics.py \
  -R ../../data/test/no_reverb/clean \
  -E out_our/enhanced_0003 \
  -M SI_SDR,STOI,WB_PESQ,NB_PESQ
# Out:
# ['/content/gdrive/My Drive/Colab Notebooks/FullSubNet/recipes/dns_interspeech_2020', '/env/python', '/usr/lib/python37.zip', '/usr/lib/python3.7', '/usr/lib/python3.7/lib-dynload', '/usr/local/lib/python3.7/dist-packages', '/usr/lib/python3/dist-packages', '/content/gdrive/My Drive/Colab Notebooks/FullSubNet']
# === out_our/enhanced_0003 === ../../data/test/no_reverb/clean ===
# 30it [00:00, 3276.54it/s]
# SI_SDR: 8.137528697649637
# 30it [00:00, 17432.68it/s]
# STOI: 0.8715308696291119
# 30it [00:00, 30437.62it/s]
# WB_PESQ: 1.7533333778381348
# 30it [00:00, 40590.04it/s]
# NB_PESQ: 2.3151440382003785

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Colab Notebooks/FullSubNet/.git/

# %%
# !git remote add origin https://mohammadian1399:github1212@github.com/mohammadian1399/speech-processing-project.git

# %%
# !git add -A
# Out:
# ^C

# %%
# !ls
# Out:
# audio_zen  audio_zen2  data  dns-data  docs  recipes  tools  train

# %%
# !echo "data" >> .gitignore

# %%
# !echo "dns-data" >> .gitignore

# %%
# !echo "train" >> .gitignore

# %%
# !echo "audio_zen2" >> .gitignore

# %%
# !echo "docs" >> .gitignore

# %%
# !ls
# Out:
# audio_zen  audio_zen2  data  dns-data  docs  recipes  tools  train

# %%
# !echo "docs" >> .gitignore
